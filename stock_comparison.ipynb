# %%
#import python libraries
import yfinance as yf
import numpy as np
import pandas as pd
from datetime import datetime,timedelta
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %%
#select the tickers
tickers=['IBM','GOOG','AMZN']
tickers
# Out:
# ['IBM', 'GOOG', 'AMZN']

# %%
#selectionner la période

# %%
end_date=datetime.today()
end_date
# Out:
# datetime.datetime(2023, 11, 13, 14, 26, 23, 742844)

# %%
start_date=end_date - timedelta(days=2*365)
start_date
# Out:
# datetime.datetime(2021, 11, 13, 14, 26, 23, 742844)

# %%
#create a dataframe to store close prices
close_df=pd.DataFrame()

# %%
for ticker in tickers:
  data=yf.download(ticker,start=start_date,end=end_date)
  close_df[ticker]=data['Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
#afficher les prix de cloture
close_df
# Out:
#                    IBM        GOOG        AMZN
# Date
# 2021-11-15  118.870003  149.388000  177.283997
# 2021-11-16  118.459999  149.076004  177.035004
# 2021-11-17  118.059998  149.061996  177.449997
# 2021-11-18  116.660004  150.709000  184.802994
# 2021-11-19  116.050003  149.952499  183.828506
# ...                ...         ...         ...
# 2023-11-07  148.830002  132.399994  142.710007
# 2023-11-08  148.029999  133.259995  142.080002
# 2023-11-09  146.619995  131.690002  140.600006
# 2023-11-10  149.020004  134.059998  143.559998
# 2023-11-13  148.380005  133.610001  141.990005
#
# [502 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# close_df['IBM'].plot(kind='hist', bins=20, title='IBM')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# close_df['GOOG'].plot(kind='hist', bins=20, title='GOOG')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# close_df['AMZN'].plot(kind='hist', bins=20, title='AMZN')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# close_df.plot(kind='scatter', x='IBM', y='GOOG', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# close_df.plot(kind='scatter', x='GOOG', y='AMZN', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# close_df['IBM'].plot(kind='line', figsize=(8, 4), title='IBM')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# close_df['GOOG'].plot(kind='line', figsize=(8, 4), title='GOOG')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# close_df['AMZN'].plot(kind='line', figsize=(8, 4), title='AMZN')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
close_df['GOOG'].plot(kind='line', figsize=(8, 4), title='GOOG')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
#calculer les rendements
returns=close_df.pct_change()
returns
# Out:
#                  IBM      GOOG      AMZN
# Date
# 2021-11-15       NaN       NaN       NaN
# 2021-11-16 -0.003449 -0.002088 -0.001404
# 2021-11-17 -0.003377 -0.000094  0.002344
# 2021-11-18 -0.011858  0.011049  0.041437
# 2021-11-19 -0.005229 -0.005020 -0.005273
# ...              ...       ...       ...
# 2023-11-07 -0.000940  0.007227  0.021254
# 2023-11-08 -0.005375  0.006495 -0.004415
# 2023-11-09 -0.009525 -0.011781 -0.010417
# 2023-11-10  0.016369  0.017997  0.021053
# 2023-11-13 -0.004295 -0.003357 -0.010936
#
# [502 rows x 3 columns]

# %%
#calculer le rendement moyen et la variance de chaque titre
mean_return=np.mean(returns,axis=0)
mean_return
# Out:
# IBM     0.000528
# GOOG    0.000019
# AMZN   -0.000081
# dtype: float64

# %%
#presenter la matrice var-cov

cov_matrix=returns.cov()
cov_matrix
# Out:
#            IBM      GOOG      AMZN
# IBM   0.000171  0.000085  0.000089
# GOOG  0.000085  0.000484  0.000410
# AMZN  0.000089  0.000410  0.000725

# %%
title='Portfolio Price History'
mes_actions=close_df

# %%
from matplotlib import pyplot as plt

# Assuming close_df is a DataFrame with columns 'GOOG', 'IBM', and 'AMZN'
close_df[['GOOG', 'IBM', 'AMZN']].plot(kind='line', figsize=(8, 4))
plt.title('Stock Prices Comparison')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend(['GOOG', 'IBM', 'AMZN'])
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()
